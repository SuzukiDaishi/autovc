# %%
import torch
import librosa
import pickle
from synthesis import build_model
from synthesis import wavegen

spect_vc = pickle.load(open('results.pkl', 'rb'))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = build_model().to(device)
checkpoint = torch.load("checkpoint_step001000000_ema.pth", map_location=device)
model.load_state_dict(checkpoint["state_dict"])

for spect in spect_vc:
    name = spect[0]
    c = spect[1]
    print(name)
    waveform = wavegen(model, c=c)   
    librosa.output.write_wav(name+'.wav', waveform, sr=16000)
# Out:
# jvs001xjvs001
# 100%|██████████| 207104/207104 [46:02<00:00, 74.98it/s]
# jvs001xjvs002
#   0%|          | 475/207104 [00:06<44:07, 78.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ba598a9ced0e> in <module>
#      15     c = spect[1]
#      16     print(name)
# ---> 17     waveform = wavegen(model, c=c)
#      18     librosa.output.write_wav(name+'.wav', waveform, sr=16000)
#
# ~/Desktop/autovc/synthesis.py in wavegen(model, c, tqdm)
#      65
#      66     with torch.no_grad():
# ---> 67         y_hat = model.incremental_forward(
#      68             initial_input, c=c, g=None, T=length, tqdm=tqdm, softmax=True, quantize=True,
#      69             log_scale_min=hparams.log_scale_min)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/wavenet_vocoder/wavenet.py in incremental_forward(self, initial_input, c, g, T, test_inputs, tqdm, softmax, quantize, log_scale_min)
#     336             skips = None
#     337             for f in self.conv_layers:
# --> 338                 x, h = f.incremental_forward(x, ct, gt)
#     339                 if self.legacy:
#     340                     skips = h if skips is None else (skips + h) * math.sqrt(0.5)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/wavenet_vocoder/modules.py in incremental_forward(self, x, c, g)
#     133
#     134     def incremental_forward(self, x, c=None, g=None):
# --> 135         return self._forward(x, c, g, True)
#     136
#     137     def _forward(self, x, c, g, is_incremental):
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/wavenet_vocoder/modules.py in _forward(self, x, c, g, is_incremental)
#     151         if is_incremental:
#     152             splitdim = -1
# --> 153             x = self.conv.incremental_forward(x)
#     154         else:
#     155             splitdim = 1
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/wavenet_vocoder/conv.py in incremental_forward(self, input)
#      43             if dilation > 1:
#      44                 input = input[:, 0::dilation, :].contiguous()
# ---> 45         output = F.linear(input.view(bsz, -1), weight, self.bias)
#      46         return output.view(bsz, 1, -1)
#      47
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
import IPython.display
IPython.display.Audio(waveform, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
